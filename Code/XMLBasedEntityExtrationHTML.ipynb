# %%
#Installations
# ?!pip install beautifulsoup4
# !pip install html5lib

# %%
#Access to Drive
from google.colab import drive
drive.mount ('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %ls "gdrive/MyDrive/Colab Notebooks/SEO Schema.org/DataSet/xmlTagged/"
# Out:
# 001.html  003.html  005.html  007.html  009.html
# 002.html  004.html  006.html  008.html  011.html

# %%
#imports
import sys
import os

import glob
from bs4 import BeautifulSoup, Comment
import html5lib
import codecs
import re

py_file_location = "/content/gdrive/MyDrive/SEO Schema.org/Code/"
sys.path.append(os.path.abspath(py_file_location))

import XMLPatterns
import DictionaryCreator
import XMLTagReplacer

# %%
#Globals
htmlLabeledDataPath =  "gdrive/MyDrive/Colab Notebooks/SEO Schema.org/DataSet/xmlTagged/*.html"
entityDictionaryPath = "gdrive/MyDrive/Colab Notebooks/SEO Schema.org/DataSet/Dictionary/pattern.csv"
EntityLabeledDataPath =  "gdrive/MyDrive/Colab Notebooks/SEO Schema.org/DataSet/xmlTagsReplaced/"

patterns = XMLPatterns()

# %%
# dc = DictionaryCreator()
# dc.processLabeledData()

# %%
# TagReplace= XMLTagReplacer()
# TagReplace.processLabeledData()

# %%
def main():
  TagReplace= XMLTagReplacer()
  TagReplace.processLabeledData()
  dc = DictionaryCreator()  
  dc.processLabeledData()
  
  return; 
if __name__=="__main__":
  main()
